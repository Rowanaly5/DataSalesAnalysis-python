# %% [markdown]
# # Day Three: Pandas Exercise: Sales Analysis

# %% [markdown]
# ### Import necessary libraries updated them if needed
# > Numpy - Matplotlib - Pandas - Seaborn - Operating System

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # Step One: Collect Data

# %% [markdown]
# #### Merge data of each month into one CSV
# In the given folder (Sales Data), you will find a group of csv files. Merge them in one data frame, then save them in a separate csv file

# %%
import glob
import pandas as pd

# get data file names
path =r'sales_data'
filenames = glob.glob(path + "/*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename))

# Concatenate all data into one DataFrame
df = pd.concat(dfs, ignore_index=True)

# %% [markdown]
# ### Read the updated dataframe

# %%
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# ### Investigating the Data
# Read the itemdescription.txt to understand the given data.
#
# Explore the data and comment on it

# %%
df.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count     186305                186305           186305     186305
# unique    178438                    20               10         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq         355                 21903           168552      21903
#
#         Order Date  Purchase Address
# count       186305            186305
# unique      142396            140788
# top     Order Date  Purchase Address
# freq           355               355

# %%
df.shape
# Out:
# (186850, 6)

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
df.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
df2 = pd.read_csv('itemdescription.txt')
df2
# Out:
#   Order ID: A unique number that is given for every purchase order (can be repeated if the order composed of several products)
# 0  Product: The name of the product that is purch...
# 1  Quantity Ordered: The number of items purchase...
# 2         Price Each: The unit price of this product
# 3             Order Date: The date of purchase order
# 4  Purchase Address: The place where the purchase...

# %%
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# ### Comment on the Data

# %% [markdown]
# ## Preparing and Cleaning up the data!
# The first step in this is figuring out what we need to clean. I have found in practice, that you find things you need to clean as you perform operations and get errors. Based on the error, you decide how you should go about cleaning the data

# %%
df.drop_duplicates(keep=False,inplace=True)

# %%
df.shape
# Out:
# (185422, 6)

# %%
df.isna().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Order ID', 'Product', 'Quantity Ordered', 'Price Each', 'Order Date',
#        'Purchase Address'],
#       dtype='object')

# %% [markdown]
# ## Data Exploration!

# %% [markdown]
# * Question 1: What was the best month for sales? How much was the total sales in that month? (Analatically and graphically)
# * Question 2: Which city have sold the most products?
# * Question 3: What time should we display advertisements to maximize likelihood of customer's buying product?
# * Question 4: What products are most often sold together? (Bonus)
# * Question 5: What product sold the most? Why do you think it sold the most?
#
# > Comment on each result

# %%
df['Price Each']=df['Price Each'].astype(str).astype(float)
df['Quantity Ordered']=df['Quantity Ordered'].astype(str).astype(float)

# %%
rev =(df['Price Each'] *df['Quantity Ordered'])
rev
# Out:
# 0          23.90
# 2          99.99
# 3         600.00
# 4          11.99
# 5          11.99
#            ...
# 186845      8.97
# 186846    700.00
# 186847    700.00
# 186848    379.99
# 186849     11.95
# Length: 185422, dtype: float64

# %%
total=rev.sum()
total
# Out:
# 34439039.91

# %%
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable               2.0       11.95
# 2        176559  Bose SoundSport Headphones               1.0       99.99
# 3        176560                Google Phone               1.0      600.00
# 4        176560            Wired Headphones               1.0       11.99
# 5        176561            Wired Headphones               1.0       11.99
# ...         ...                         ...               ...         ...
# 186845   259353      AAA Batteries (4-pack)               3.0        2.99
# 186846   259354                      iPhone               1.0      700.00
# 186847   259355                      iPhone               1.0      700.00
# 186848   259356      34in Ultrawide Monitor               1.0      379.99
# 186849   259357        USB-C Charging Cable               1.0       11.95
#
#             Order Date                         Purchase Address
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
#df.insert(2, "Month", df['Order Date'].dt.month)
#df.insert(3, "Year", df['Order Date'].dt.year)

# %%
df.insert(4, "Hour", df['Order Date'].dt.hour)

# %%
df.insert(4, "revenue", (df['Price Each'] *df['Quantity Ordered']))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185422 entries, 0 to 186849
# Data columns (total 9 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185422 non-null  object
#  1   Product           185422 non-null  object
#  2   Month             185422 non-null  int64
#  3   Year              185422 non-null  int64
#  4   revenue           185422 non-null  float64
#  5   Quantity Ordered  185422 non-null  float64
#  6   Price Each        185422 non-null  float64
#  7   Order Date        185422 non-null  datetime64[ns]
#  8   Purchase Address  185422 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(2), object(3)
# memory usage: 14.1+ MB

# %%
mergemnthandrev =  df.groupby(['Month'],as_index=False).revenue.sum()
print(mergemnthandrev)
# Out:
#     Month       revenue
# 0       1  1.820570e+06
# 1       2  2.198134e+06
# 2       3  2.802846e+06
# 3       4  3.387766e+06
# 4       5  3.148626e+06
# 5       6  2.574758e+06
# 6       7  2.645147e+06
# 7       8  2.237699e+06
# 8       9  2.091371e+06
# 9      10  3.732829e+06
# 10     11  3.196147e+06
# 11     12  4.603148e+06

# %%
max_value = mergemnthandrev.max()
max_value
# Out:
# Month      1.200000e+01
# revenue    4.603148e+06
# dtype: float64

# %%
min_value = mergemnthandrev.min()
min_value
# Out:
# Month            1.00
# revenue    1820569.59
# dtype: float64

# %%
mergemnthandrev.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Question 1: What was the best month for sales? How much was earned that month? (Analatically and graphically)
# Draw a bar chart that can idicate the month with the higest (in green) and lowest sales (in red)
# ![image.png](attachment:image.png)

# %%
colorList = []
for value in mergemnthandrev['revenue']:
    if value == mergemnthandrev['revenue'].max() :
        colorList.append('g')
    elif value == mergemnthandrev['revenue'].min() :
        colorList.append('r')
    else: 
        colorList.append('b')

# %%
plt.bar(mergemnthandrev.index,mergemnthandrev['revenue'],color = colorList)
plt.show()

# %% [markdown]
# #### Question 2: What city sold the most product?

# %%
df.head()
# Out:
#   Order ID                     Product  Month  Year  revenue  \
# 0   176558        USB-C Charging Cable      4  2019    23.90
# 2   176559  Bose SoundSport Headphones      4  2019    99.99
# 3   176560                Google Phone      4  2019   600.00
# 4   176560            Wired Headphones      4  2019    11.99
# 5   176561            Wired Headphones      4  2019    11.99
#
#    Quantity Ordered  Price Each          Order Date  \
# 0               2.0       11.95 2019-04-19 08:46:00
# 2               1.0       99.99 2019-04-07 22:30:00
# 3               1.0      600.00 2019-04-12 14:38:00
# 4               1.0       11.99 2019-04-12 14:38:00
# 5               1.0       11.99 2019-04-30 09:27:00
#
#                        Purchase Address
# 0          917 1st St, Dallas, TX 75001
# 2     682 Chestnut St, Boston, MA 02215
# 3  669 Spruce St, Los Angeles, CA 90001
# 4  669 Spruce St, Los Angeles, CA 90001
# 5     333 8th St, Los Angeles, CA 90001

# %%
df['city']=df['Purchase Address'].apply(lambda x : x.split(',')[1])

# %%
df.head()
# Out:
#   Order ID                     Product  Month  Year  revenue  \
# 0   176558        USB-C Charging Cable      4  2019    23.90
# 2   176559  Bose SoundSport Headphones      4  2019    99.99
# 3   176560                Google Phone      4  2019   600.00
# 4   176560            Wired Headphones      4  2019    11.99
# 5   176561            Wired Headphones      4  2019    11.99
#
#    Quantity Ordered  Price Each          Order Date  \
# 0               2.0       11.95 2019-04-19 08:46:00
# 2               1.0       99.99 2019-04-07 22:30:00
# 3               1.0      600.00 2019-04-12 14:38:00
# 4               1.0       11.99 2019-04-12 14:38:00
# 5               1.0       11.99 2019-04-30 09:27:00
#
#                        Purchase Address          city
# 0          917 1st St, Dallas, TX 75001        Dallas
# 2     682 Chestnut St, Boston, MA 02215        Boston
# 3  669 Spruce St, Los Angeles, CA 90001   Los Angeles
# 4  669 Spruce St, Los Angeles, CA 90001   Los Angeles
# ...

# %%
df_city=df.groupby(["city"])['revenue'].sum().sort_values(ascending=False)
df_city=df_city.to_frame()
df_city
# Out:
#                      revenue
# city
#  San Francisco  8.247283e+06
#  Los Angeles    5.444038e+06
#  New York City  4.659417e+06
#  Boston         3.655613e+06
#  Atlanta        2.792900e+06
#  Dallas         2.762773e+06
#  Seattle        2.742337e+06
#  Portland       2.318173e+06
#  Austin         1.816507e+06

# %%
plt.bar(df_city.index , df_city['revenue'])
plt.xticks(city , rotation='vertical',size=8)

plt.show()

# %% [markdown]
# #### Question 3: What time should we display advertisements to maximize likelihood of customer's buying product?
# Plot the number of purchase orders done in every hour and mark the higest hour

# %%
df
# Out:
#        Order ID                     Product  Month  Year  Hour      Time  \
# 0        176558        USB-C Charging Cable      4  2019     8  08:46:00
# 2        176559  Bose SoundSport Headphones      4  2019    22  22:30:00
# 3        176560                Google Phone      4  2019    14  14:38:00
# 4        176560            Wired Headphones      4  2019    14  14:38:00
# 5        176561            Wired Headphones      4  2019     9  09:27:00
# ...         ...                         ...    ...   ...   ...       ...
# 186845   259353      AAA Batteries (4-pack)      9  2019    20  20:56:00
# 186846   259354                      iPhone      9  2019    16  16:00:00
# 186847   259355                      iPhone      9  2019     7  07:39:00
# 186848   259356      34in Ultrawide Monitor      9  2019    17  17:30:00
# 186849   259357        USB-C Charging Cable      9  2019     0  00:18:00
#
#         revenue  Quantity Ordered  Price Each          Order Date  \
# ...

# %%
df_t=df.groupby(['Hour'])['revenue'].sum().sort_values(ascending=True).head()
df_t=df_t.to_frame()
df_t
# Out:
#         revenue
# Hour
# 3     145727.99
# 4     162431.13
# 5     230649.92
# 2     234827.46
# 6     447813.02

# %%
#df_t=df.groupby(['Hour'])['revenue'].sum().sort_values(ascending=True).head()
#df_t=df_t.to_frame()
#df_t
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-312-58c11fed821f> in <module>
# ----> 1 df_t=df.groupby(['Hour']).value_counts()
#       2 df_t=df_t.to_frame()
#       3 df_t
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     701             return self[attr]
#     702
# --> 703         raise AttributeError(
#     704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'value_counts'

# %%
counthours=df['Hour'].value_counts()
counthours.plot(kind='barh',title="top hours")
# Out:
# <AxesSubplot:title={'center':'top hours'}>

# %% [markdown]
# #### Question 4: What products are most often sold together?

# %%
Dupl_order = df[df['Order ID'].duplicated(keep=False)]
Dupl_order
# Out:
#        Order ID                 Product  Month  Year  Hour      Time  revenue  \
# 3        176560            Google Phone      4  2019    14  14:38:00   600.00
# 4        176560        Wired Headphones      4  2019    14  14:38:00    11.99
# 18       176574            Google Phone      4  2019    19  19:42:00   600.00
# 19       176574    USB-C Charging Cable      4  2019    19  19:42:00    11.95
# 32       176586  AAA Batteries (4-pack)      4  2019    17  17:00:00     5.98
# ...         ...                     ...    ...   ...   ...       ...      ...
# 186792   259303   AA Batteries (4-pack)      9  2019    20  20:18:00     3.84
# 186803   259314        Wired Headphones      9  2019     0  00:25:00    11.99
# 186804   259314  AAA Batteries (4-pack)      9  2019     0  00:25:00     5.98
# 186841   259350            Google Phone      9  2019    13  13:49:00   600.00
# 186842   259350    USB-C Charging Cable      9  2019    13  13:49:00    11.95
#
# ...

# %%
Dupl_order['Product_Order'] = Dupl_order.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
Dupl_order
# Out:
# <ipython-input-328-e6fb2a377776>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Dupl_order['Product_Order'] = Dupl_order.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
#        Order ID                 Product  Month  Year  Hour      Time  revenue  \
# 3        176560            Google Phone      4  2019    14  14:38:00   600.00
# 4        176560        Wired Headphones      4  2019    14  14:38:00    11.99
# 18       176574            Google Phone      4  2019    19  19:42:00   600.00
# 19       176574    USB-C Charging Cable      4  2019    19  19:42:00    11.95
# 32       176586  AAA Batteries (4-pack)      4  2019    17  17:00:00     5.98
# ...

# %%
Dupl_order['Quantity Ordered'].max()
# Out:
# 7.0

# %%
from itertools import combinations
from collections import Counter

count_2product = Counter()
count_3product = Counter()
count_4product = Counter()
count_5product = Counter()
count_6product = Counter()
count_7product = Counter()
for row in Dupl_order['Product_Order']:
    row_list = row.split(',')
    count_2product.update(Counter(combinations(row_list,2)))
    count_3product.update(Counter(combinations(row_list,3)))
    count_4product.update(Counter(combinations(row_list,4)))
    count_5product.update(Counter(combinations(row_list,5)))
    count_6product.update(Counter(combinations(row_list,6)))
    count_7product.update(Counter(combinations(row_list,7)))
    
print(count_2product.most_common(10))
# Out:
# [(('iPhone', 'Lightning Charging Cable'), 2119), (('Google Phone', 'USB-C Charging Cable'), 2100), (('iPhone', 'Wired Headphones'), 987), (('Google Phone', 'Wired Headphones'), 939), (('iPhone', 'Apple Airpods Headphones'), 799), (('Vareebadd Phone', 'USB-C Charging Cable'), 773), (('Google Phone', 'Bose SoundSport Headphones'), 503), (('USB-C Charging Cable', 'Wired Headphones'), 440), (('Vareebadd Phone', 'Wired Headphones'), 327), (('Lightning Charging Cable', 'Wired Headphones'), 253)]

# %%
print(count_2product.most_common(1))
print(count_3product.most_common(1))
print(count_4product.most_common(1))
# Out:
# [(('iPhone', 'Lightning Charging Cable'), 2119)]
# [(('Google Phone', 'USB-C Charging Cable', 'Wired Headphones'), 259)]
# [(('iPhone', 'Lightning Charging Cable', 'Apple Airpods Headphones', 'Wired Headphones'), 17)]

# %% [markdown]
# #### Question 5: What product sold the most? Why do you think it sold the most?

# %%
print(df["Product"].unique())
print(df["Product"].nunique())
# Out:
# ['USB-C Charging Cable' 'Bose SoundSport Headphones' 'Google Phone'
#  'Wired Headphones' 'Macbook Pro Laptop' 'Lightning Charging Cable'
#  '27in 4K Gaming Monitor' 'AA Batteries (4-pack)'
#  'Apple Airpods Headphones' 'AAA Batteries (4-pack)' 'iPhone'
#  'Flatscreen TV' '27in FHD Monitor' '20in Monitor' 'LG Dryer'
#  'ThinkPad Laptop' 'Vareebadd Phone' 'LG Washing Machine'
#  '34in Ultrawide Monitor']
# 19

# %%
df_p=df.groupby(['Product'])['Quantity Ordered'].sum().sort_values(ascending=False).head()
df_p=df_p.to_frame()
df_p
# Out:
#                           Quantity Ordered
# Product
# AAA Batteries (4-pack)             30955.0
# AA Batteries (4-pack)              27595.0
# USB-C Charging Cable               23887.0
# Lightning Charging Cable           23121.0
# Wired Headphones                   20491.0
